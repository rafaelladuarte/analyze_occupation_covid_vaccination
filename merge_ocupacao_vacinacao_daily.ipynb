# %%
import pandas as pd

# %%
path_vac = 'brasil_vacinacao_daily.csv'
path_ocu = 'brasil_ocupacao_daily.csv'

# %%
df_vac = pd.read_csv(path_vac)
df_ocu = pd.read_csv(path_ocu)

# %%
df_vac
# Out:
#      Unnamed: 0        date  total_cases  new_cases  total_deaths  new_deaths  \
# 0         28061  2020-02-26            1          1             0           0
# 1         28062  2020-02-27            1          0             0           0
# 2         28063  2020-02-28            1          0             0           0
# 3         28064  2020-02-29            2          1             0           0
# 4         28065  2020-03-01            2          0             0           0
# ..          ...         ...          ...        ...           ...         ...
# 967       29028  2022-10-20     34771320          0        687423           0
# 968       29029  2022-10-21     34780462       9142        687527         104
# 969       29030  2022-10-22     34780462          0        687527           0
# 970       29031  2022-10-23     34780462          0        687527           0
# 971       29032  2022-10-24     34783786       3324        687574          47
#
# ...

# %%
df_ocu
# Out:
#       Unnamed: 0  datacode  ocupacaoSuspeitoUti  ocupacaoConfirmadoCli  \
# 0              0  20200101                   47                     49
# 1              1  20200102                  260                    213
# 2              2  20200103                  249                    201
# 3              3  20200104                  150                     78
# 4              4  20200105                   57                     79
# ...          ...       ...                  ...                    ...
# 1019        1019  20221016                    0                      0
# 1020        1020  20221017                    0                      0
# 1021        1021  20221018                    0                      0
# 1022        1022  20221019                    0                      0
# 1023        1023  20221020                    0                      0
#
#       ocupacaoConfirmadoUti  ocupacaoCovidUti  ocupacaoCovidCli  \
# ...

# %%
df_ocu.drop(columns=['Unnamed: 0'],inplace=True)
df_vac.drop(columns=['Unnamed: 0'],inplace=True)

# %%
df_ocu
# Out:
#       datacode  ocupacaoSuspeitoUti  ocupacaoConfirmadoCli  \
# 0     20200101                   47                     49
# 1     20200102                  260                    213
# 2     20200103                  249                    201
# 3     20200104                  150                     78
# 4     20200105                   57                     79
# ...        ...                  ...                    ...
# 1019  20221016                    0                      0
# 1020  20221017                    0                      0
# 1021  20221018                    0                      0
# 1022  20221019                    0                      0
# 1023  20221020                    0                      0
#
#       ocupacaoConfirmadoUti  ocupacaoCovidUti  ocupacaoCovidCli  \
# 0                        30                 0                 0
# 1                       215                 0                 6
# ...

# %%
df_vac
# Out:
#      total_cases  new_cases  total_deaths  new_deaths  total_vaccinations  \
# 0              1          1             0           0                   0
# 1              1          0             0           0                   0
# 2              1          0             0           0                   0
# 3              2          1             0           0                   0
# 4              2          0             0           0                   0
# ..           ...        ...           ...         ...                 ...
# 967     34771320          0        687423           0           473101635
# 968     34780462       9142        687527         104           473101789
# 969     34780462          0        687527           0           473101982
# 970     34780462          0        687527           0           473101996
# 971     34783786       3324        687574          47           473102012
#
#      people_vaccinated  new_vaccinations  datacode
# ...

# %%
df_merge = pd.merge( df_vac,df_ocu, on="datacode")

# %%
df_merge.to_csv('brasil_merge_ocupacao_vacinacao_daily.csv')
